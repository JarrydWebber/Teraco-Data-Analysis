# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
new_frame = pd.read_csv("Cape Town WWise_2021-12-07-11-36-18.csv", delimiter = ";")

data = new_frame[["CT1_TEM2.C_TEM_2_MLV_A_UPS#Real Energy Into the Load#kWh"]].replace(',', '.', regex=True).astype(float).dropna()

plt.plot(data.diff(), '.')

# %%
new_frame = pd.read_csv("Cape Town WWise_2022-01-21-11-37-24.csv", delimiter = ";")

data = new_frame[["CT1_TEM2.C_TEM_2_MLV_A_UPS#Real Energy Into the Load#kWh"]].replace(',', '.', regex=True).astype(float).dropna()

plt.plot(data.diff(), '.')

# %%
new_frame = pd.read_csv("Cape Town WWise_2022-03-07-08-45-38.csv", delimiter = ";")

data = new_frame[["CT1_TEM2.C_TEM_2_MLV_A_UPS#Real Energy Into the Load#kWh", "CT1_TEM2.C_TEM_2_MLV_B_UPS#Real Energy Into the Load#kWh"]].replace(',', '.', regex=True).astype(float).dropna()

plt.plot(data.diff(), '.')
