# %%
import sys
import pandas as pd

# %%
sys.path
# Out:
# ['C:\\Users\\Jarryd Webber\\Desktop\\Teraco\\Teraco-Data-Analysis\\All Teraco Data\\Operations CT1 - NNLS',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\\python39.zip',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\\DLLs',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\\lib',
#  'C:\\Users\\Jarryd Webber\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0',
#  '',
#  'C:\\Users\\Jarryd Webber\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages',
#  'C:\\Users\\Jarryd Webber\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\win32',
# ...

# %%
# !pip show sklearn
# Out:
# Name: sklearn
# Version: 0.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://pypi.python.org/pypi/scikit-learn/
# Author: UNKNOWN
# Author-email: UNKNOWN
# License:
# Location: c:\python39\lib\site-packages
# Requires: scikit-learn
# Required-by:

# %%
"C:\python39\lib\site-packages" in sys.path
# Out:
# True

# %%
"C:\\Users\\Jarryd Webber\\.ipython" in sys.path
# Out:
# True

# %%
sys.path.append('C:\python39\lib\site-packages')

# %%
sys.path
# Out:
# ['C:\\Users\\Jarryd Webber\\Desktop\\Teraco\\Teraco-Data-Analysis\\All Teraco Data\\Operations CT1 - NNLS',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\\python39.zip',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\\DLLs',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_3.9.2800.0_x64__qbz5n2kfra8p0\\lib',
#  'C:\\Users\\Jarryd Webber\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0',
#  '',
#  'C:\\Users\\Jarryd Webber\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages',
#  'C:\\Users\\Jarryd Webber\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\win32',
# ...

# %%
import sklearn

# %%
pd.DataFrame()
