# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\jarry\Desktop\Teraco Demo\Teraco-Data-Analysis-main\Operations - JB\Data\\"
file = "Master.csv"
# file = "JB1 East WWise_2021-12-09-10-56-37.csv"
# file1 = "JB1 East WWise_2022-01-21-11-39-29.csv"
# file2 = "JB1 West WWise_2021-12-09-16-09-29.csv"
# file3 = "JB1 West WWise_2022-01-21-11-40-01.csv"
# file2 = "JB3 Phase 2 WWise_2022-01-21-11-31-51.csv"

# %%
data = pd.read_csv(path+file)
# data1 = pd.read_csv(path+file1, delimiter = ";")
# data2 = pd.read_csv(path+file2, delimiter = ";")
# data3 = pd.read_csv(path+file3, delimiter = ";")
# data = pd.concat([data1, data1, data2, data3])

# %%
print (data)
# Out:
#                  Timestamp  \
# 0      2021-01-01 00:15:00
# 1      2021-01-01 00:30:00
# 2      2021-01-01 00:45:00
# 3      2021-01-01 01:00:00
# 4      2021-01-01 01:15:00
# ...                    ...
# 35748  2021-12-31 23:00:00
# 35749  2021-12-31 23:15:00
# 35750  2021-12-31 23:30:00
# 35751  2021-12-31 23:45:00
# 35752  2022-01-01 00:00:00
#
#        JB1_TEM1.J_TEM_1_DB_AC1_Mainswitch#Real Energy Into the Load#kWh  \
# 0                                             10353444.0
# 1                                             10353489.0
# 2                                             10353533.0
# 3                                             10353575.0
# 4                                             10353619.0
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM1.J_TEM_1_DB_AC2_Mainswitch#Real Energy Into the Load#kWh  \
# 0                                              8966994.0
# 1                                              8967031.0
# 2                                              8967067.0
# 3                                              8967103.0
# 4                                              8967139.0
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM1.J_TEM_1_DB_CC_A_TCP#Real Energy Into the Load#kWh  \
# 0                                                    NaN
# 1                                             23754780.0
# 2                                                    NaN
# 3                                             23755410.0
# 4                                                    NaN
# ...                                                  ...
# 35748                                         34615996.0
# 35749                                         34616308.0
# 35750                                         34616616.0
# 35751                                         34616928.0
# 35752                                         34617236.0
#
#        JB1_TEM1.J_TEM_1_GeneratorAController#Real Energy Into the Load#kWh  \
# 0                                                16483.0
# 1                                                16483.0
# 2                                                16483.0
# 3                                                16483.0
# 4                                                16483.0
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM1.J_TEM_1_GeneratorBController#Real Energy Into the Load#kWh  \
# 0                                                22654.7
# 1                                                22654.7
# 2                                                22654.7
# 3                                                22654.7
# 4                                                22654.7
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM1.J_TEM_1_MDB_A_Mainswitch#Real Energy Into the Load#kWh  \
# 0                                             15927697.0
# 1                                             15927861.0
# 2                                             15928023.0
# 3                                             15928185.0
# 4                                             15928349.0
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM1.J_TEM_1_MDB_B_Mainswitch#Real Energy Into the Load#kWh  \
# 0                                             34857828.0
# 1                                             34857984.0
# 2                                             34858140.0
# 3                                             34858288.0
# 4                                             34858452.0
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM1.J_TEM_1_UPS_A_Mainswitch#Real Energy Into the Load#kWh  \
# 0                                             16297361.0
# 1                                             16297431.0
# 2                                             16297501.0
# 3                                             16297572.0
# 4                                             16297643.0
# ...                                                  ...
# 35748                                         18774266.0
# 35749                                         18774338.0
# 35750                                         18774406.0
# 35751                                         18774474.0
# 35752                                         18774546.0
#
#        JB1_TEM1.J_TEM_1_UPS_B_Mainswitch#Real Energy Into the Load#kWh  ...  \
# 0                                             14891573.0                ...
# 1                                             14891638.0                ...
# 2                                             14891703.0                ...
# 3                                             14891767.0                ...
# 4                                             14891833.0                ...
# ...                                                  ...                ...
# 35748                                         17200178.0                ...
# 35749                                         17200246.0                ...
# 35750                                         17200314.0                ...
# 35751                                         17200382.0                ...
# 35752                                         17200448.0                ...
#
#        JB1_TEM7.J_TEM_7_Generator_A_Supply#Real Energy Into the Load#kWh  \
# 0                                                    NaN
# 1                                            7929.800293
# 2                                                    NaN
# 3                                            7929.800293
# 4                                                    NaN
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_Generator_B_Supply#Real Energy Into the Load#kWh  \
# 0                                                    NaN
# 1                                            6047.724609
# 2                                                    NaN
# 3                                            6047.724609
# 4                                                    NaN
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_Generator_C_Supply#Real Energy Into the Load#kWh  \
# 0                                                    NaN
# 1                                            9412.289062
# 2                                                    NaN
# 3                                            9412.289062
# 4                                                    NaN
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_HVAC_B#Real Energy Into the Load#kWh  \
# 0                                             414092.048
# 1                                             414132.219
# 2                                             414171.975
# 3                                             414210.165
# 4                                             414249.994
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_HVAC_C#Real Energy Into the Load#kWh  \
# 0                                             431388.120
# 1                                             431391.722
# 2                                             431395.776
# 3                                             431396.770
# 4                                             431398.594
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_Hvac_System_A#Real Energy Into the Load#kWh  \
# 0                                             392400.331
# 1                                             392402.243
# 2                                             392404.676
# 3                                             392407.682
# 4                                             392410.209
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_Main_Incomer_HT#Real Energy Into the Load#kWh  \
# 0                                                    NaN
# 1                                             3302186.25
# 2                                                    NaN
# 3                                             3302628.00
# 4                                                    NaN
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_MLV_A#Real Energy Into the Load#kWh  \
# 0                                            2438365.979
# 1                                            2438427.304
# 2                                            2438489.243
# 3                                            2438550.477
# 4                                            2438611.533
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_MLV_B#Real Energy Into the Load#kWh  \
# 0                                            1927305.784
# 1                                            1927398.426
# 2                                            1927490.552
# 3                                            1927580.549
# 4                                            1927673.126
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
#        JB1_TEM7.J_TEM_7_MLV_C#Real Energy Into the Load#kWh
# 0                                            2504325.232
# 1                                            2504390.076
# 2                                            2504455.287
# 3                                            2504516.733
# 4                                            2504579.017
# ...                                                  ...
# 35748                                                NaN
# 35749                                                NaN
# 35750                                                NaN
# 35751                                                NaN
# 35752                                                NaN
#
# [35753 rows x 99 columns]

# %%
column_list = []
tems_list = []
paired = []
for column in data.columns:
    col = column.split("#")[0].split('.')[-1]
    tem = column.split("#")[0].split('.')[0].split('_')[-1]
    column_list.append(col)
    tems_list.append(tem)
    paired.append([col, column, tem])
# column_list

# %%
storing_frame = pd.DataFrame(data = paired[1:], columns = ["Name", "Full Name", "TEM"])
storing_frame["Type"] = np.zeros(len(data.columns)-1)
storing_frame["Energy Flow"] = np.zeros(len(data.columns)-1)

# %%
for row in storing_frame.index:
#     print (row)
    for category in ["UPS", "HVAC", "Generator", "Solar"]:
        if category in storing_frame.loc[row]["Name"]:
            storing_frame.loc[row , "Type"] = category
    if "Gen" in storing_frame.loc[row]["Name"]:
        storing_frame.loc[row , "Type"] = "Generator"
    storing_frame["Type"].replace(0,"Mains", inplace = True)
    
    if storing_frame.loc[row,"Type"] in ["Generator", "Mains", "Solar"]:
        storing_frame.loc[row,"Energy Flow"] = "Incoming"
    else:
        storing_frame.loc[row,"Energy Flow"] = "Outgoing"

# %%
storing_frame
# Out:
#                             Name  \
# 0      J_TEM_1_DB_AC1_Mainswitch
# 1      J_TEM_1_DB_AC2_Mainswitch
# 2            J_TEM_1_DB_CC_A_TCP
# 3   J_TEM_1_GeneratorAController
# 4   J_TEM_1_GeneratorBController
# ..                           ...
# 93         J_TEM_7_Hvac_System_A
# 94       J_TEM_7_Main_Incomer_HT
# 95                 J_TEM_7_MLV_A
# 96                 J_TEM_7_MLV_B
# 97                 J_TEM_7_MLV_C
#
#                                             Full Name   TEM       Type  \
# 0   JB1_TEM1.J_TEM_1_DB_AC1_Mainswitch#Real Energy...  TEM1      Mains
# 1   JB1_TEM1.J_TEM_1_DB_AC2_Mainswitch#Real Energy...  TEM1      Mains
# 2   JB1_TEM1.J_TEM_1_DB_CC_A_TCP#Real Energy Into ...  TEM1      Mains
# 3   JB1_TEM1.J_TEM_1_GeneratorAController#Real Ene...  TEM1  Generator
# 4   JB1_TEM1.J_TEM_1_GeneratorBController#Real Ene...  TEM1  Generator
# ..                                                ...   ...        ...
# 93  JB1_TEM7.J_TEM_7_Hvac_System_A#Real Energy Int...  TEM7      Mains
# 94  JB1_TEM7.J_TEM_7_Main_Incomer_HT#Real Energy I...  TEM7      Mains
# 95  JB1_TEM7.J_TEM_7_MLV_A#Real Energy Into the Lo...  TEM7      Mains
# 96  JB1_TEM7.J_TEM_7_MLV_B#Real Energy Into the Lo...  TEM7      Mains
# 97  JB1_TEM7.J_TEM_7_MLV_C#Real Energy Into the Lo...  TEM7      Mains
#
#    Energy Flow
# 0     Incoming
# 1     Incoming
# 2     Incoming
# 3     Incoming
# 4     Incoming
# ..         ...
# 93    Incoming
# 94    Incoming
# 95    Incoming
# 96    Incoming
# 97    Incoming
#
# [98 rows x 5 columns]

# %%
storing_frame.to_csv(path+"Name_list.csv")
